# %% [markdown]
# # Challenge 06 - Agentic AI
#
# In this notebook, you will build a **Research Assistant Agent** using the Microsoft Agent Framework. This agent leverages **Model Context Protocol (MCP)** to connect to live data sources like Microsoft Learn documentation.

# %% [markdown]
# Quick tip! To view the Table of Contents for this Notebook in VS Code or within Codespaces, take a look at the "Explorer" tab, expand the "Outline" section.

# %% [markdown]
# ## 6.1. Setting Up Your Environment
#
# First, install the Microsoft Agent Framework. The `--pre` flag is required while the Agent Framework is in preview.

# %%
# %pip install agent-framework-azure-ai --pre
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting agent-framework-azure-ai
#   Downloading agent_framework_azure_ai-1.0.0rc1-py3-none-any.whl.metadata (1.4 kB)
# Collecting agent-framework-core>=1.0.0rc1 (from agent-framework-azure-ai)
#   Downloading agent_framework_core-1.0.0rc1-py3-none-any.whl.metadata (10.0 kB)
# Collecting azure-ai-agents==1.2.0b5 (from agent-framework-azure-ai)
#   Downloading azure_ai_agents-1.2.0b5-py3-none-any.whl.metadata (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.7/74.7 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework-azure-ai) (3.13.3)
# Requirement already satisfied: isodate>=0.6.1 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (1.38.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (4.15.0)
# Requirement already satisfied: pydantic<3,>=2 in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (2.11.10)
# Requirement already satisfied: python-dotenv<2,>=1 in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (1.2.1)
# Requirement already satisfied: opentelemetry-api>=1.39.0 in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.39.0 in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (1.39.1)
# Collecting opentelemetry-semantic-conventions-ai>=0.4.13 (from agent-framework-core>=1.0.0rc1->agent-framework-azure-ai)
#   Downloading opentelemetry_semantic_conventions_ai-0.4.13-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: openai>=1.99.0 in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (2.21.0)
# Requirement already satisfied: azure-identity<2,>=1 in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (1.25.2)
# Requirement already satisfied: azure-ai-projects>=2.0.0b3 in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (2.0.0b3)
# Collecting mcp<2,>=1.24.0 (from mcp[ws]<2,>=1.24.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai)
#   Downloading mcp-1.26.0-py3-none-any.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 20.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=24.1 in /home/vscode/.local/lib/python3.11/site-packages (from agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (26.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->agent-framework-azure-ai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->agent-framework-azure-ai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->agent-framework-azure-ai) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->agent-framework-azure-ai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->agent-framework-azure-ai) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->agent-framework-azure-ai) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp->agent-framework-azure-ai) (1.22.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-projects>=2.0.0b3->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (12.28.0)
# Requirement already satisfied: requests>=2.21.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-core>=1.30.0->azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (2.32.5)
# Requirement already satisfied: cryptography>=2.5 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity<2,>=1->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (46.0.5)
# Requirement already satisfied: msal>=1.31.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity<2,>=1->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity<2,>=1->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (1.3.1)
# Requirement already satisfied: anyio>=4.5 in /home/vscode/.local/lib/python3.11/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (4.12.1)
# Collecting httpx-sse>=0.4 (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: httpx>=0.27.1 in /home/vscode/.local/lib/python3.11/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/vscode/.local/lib/python3.11/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /home/vscode/.local/lib/python3.11/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (2.13.1)
# Requirement already satisfied: pyjwt>=2.10.1 in /home/vscode/.local/lib/python3.11/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (2.11.0)
# Collecting python-multipart>=0.0.9 (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai)
#   Downloading python_multipart-0.0.22-py3-none-any.whl.metadata (1.8 kB)
# Collecting sse-starlette>=1.6.1 (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai)
#   Downloading sse_starlette-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: starlette>=0.27 in /home/vscode/.local/lib/python3.11/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.1 in /home/vscode/.local/lib/python3.11/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /home/vscode/.local/lib/python3.11/site-packages (from mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (0.41.0)
# Requirement already satisfied: websockets>=15.0.1 in /home/vscode/.local/lib/python3.11/site-packages (from mcp[ws]<2,>=1.24.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/vscode/.local/lib/python3.11/site-packages (from openai>=1.99.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /home/vscode/.local/lib/python3.11/site-packages (from openai>=1.99.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (0.13.0)
# Requirement already satisfied: sniffio in /home/vscode/.local/lib/python3.11/site-packages (from openai>=1.99.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/vscode/.local/lib/python3.11/site-packages (from openai>=1.99.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (4.67.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/vscode/.local/lib/python3.11/site-packages (from opentelemetry-api>=1.39.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (8.7.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /home/vscode/.local/lib/python3.11/site-packages (from opentelemetry-sdk>=1.39.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (0.60b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/vscode/.local/lib/python3.11/site-packages (from pydantic<3,>=2->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/vscode/.local/lib/python3.11/site-packages (from pydantic<3,>=2->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (2.33.2)
# Requirement already satisfied: idna>=2.0 in /home/vscode/.local/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp->agent-framework-azure-ai) (3.11)
# Requirement already satisfied: cffi>=2.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from cryptography>=2.5->azure-identity<2,>=1->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (2.0.0)
# Requirement already satisfied: certifi in /home/vscode/.local/lib/python3.11/site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/vscode/.local/lib/python3.11/site-packages (from httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/vscode/.local/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /home/vscode/.local/lib/python3.11/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.39.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (3.23.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (0.36.2)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (0.30.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vscode/.local/lib/python3.11/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.11/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-agents==1.2.0b5->agent-framework-azure-ai) (2.6.3)
# Requirement already satisfied: click>=7.0 in /home/vscode/.local/lib/python3.11/site-packages (from uvicorn>=0.31.1->mcp<2,>=1.24.0->mcp[ws]<2,>=1.24.0->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (8.3.1)
# Requirement already satisfied: pycparser in /home/vscode/.local/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity<2,>=1->agent-framework-core>=1.0.0rc1->agent-framework-azure-ai) (3.0)
# Downloading agent_framework_azure_ai-1.0.0rc1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 7.2 MB/s eta 0:00:00
# Downloading azure_ai_agents-1.2.0b5-py3-none-any.whl (217 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.9/217.9 kB 22.5 MB/s eta 0:00:00
# Downloading agent_framework_core-1.0.0rc1-py3-none-any.whl (306 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.3/306.3 kB 32.3 MB/s eta 0:00:00
# Downloading mcp-1.26.0-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 28.9 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions_ai-0.4.13-py3-none-any.whl (6.1 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading python_multipart-0.0.22-py3-none-any.whl (24 kB)
# Downloading sse_starlette-3.2.0-py3-none-any.whl (12 kB)
# Installing collected packages: python-multipart, opentelemetry-semantic-conventions-ai, httpx-sse, sse-starlette, azure-ai-agents, mcp, agent-framework-core, agent-framework-azure-ai
#   Attempting uninstall: azure-ai-agents
#     Found existing installation: azure-ai-agents 1.2.0b6
#     Uninstalling azure-ai-agents-1.2.0b6:
#       Successfully uninstalled azure-ai-agents-1.2.0b6
# Successfully installed agent-framework-azure-ai-1.0.0rc1 agent-framework-core-1.0.0rc1 azure-ai-agents-1.2.0b5 httpx-sse-0.4.3 mcp-1.26.0 opentelemetry-semantic-conventions-ai-0.4.13 python-multipart-0.0.22 sse-starlette-3.2.0
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 6.1.1 Load Environment Variables
#
# Load your Microsoft Foundry project endpoint and model deployment name from the `.env` file.
#
# **NOTE:** These values in your .env file are required to ensure the notebook runs seamlessly. They should already be there if you deployed using the deployment script in Challenge 0.
# * AZURE_AI_PROJECT_ENDPOINT must equal your Microsoft Foundry project endpoint
# * CHAT_MODEL_NAME must equal the deployed model's name (e.g., `gpt-4o`)

# %%
import os

from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())

# Note: We use the async version of DefaultAzureCredential for the Agent Framework
from azure.identity.aio import DefaultAzureCredential

# %% [markdown]
# ## 6.2. Creating the Research Assistant Agent
#
# ### 6.2.1 Import Required Libraries
#
# Import the Agent Framework components and Azure Identity for authentication.

# %%
from agent_framework.azure import AzureAIClient
from agent_framework import MCPStreamableHTTPTool

# %% [markdown]
# ### 6.2.2 Define the MCP Tool
#
# Create a function that returns the MCP tool configuration for Microsoft Learn documentation. This allows your agent to query live, up-to-date documentation.

# %%
def create_mcp_tools():
    """Create MCP tools for the Research Assistant agent."""
    return [
        MCPStreamableHTTPTool(
            name="Microsoft Learn MCP",
            description="Provides trusted, up-to-date information from Microsoft's official documentation",
            url="https://learn.microsoft.com/api/mcp",
        )
    ]

# %% [markdown]
# ### 6.2.3 Define the Agent Instructions
#
# Create the system instructions that define how the Research Assistant should behave.

# %%
AGENT_INSTRUCTIONS = """
You are a helpful research assistant that specializes in Azure and Microsoft technologies. 

Your responsibilities:
1. Use the Microsoft Learn MCP tool to find accurate, up-to-date documentation when answering questions
2. Always cite your sources by providing links to the documentation
3. If you're unsure about something, acknowledge it and suggest where the user might find more information
4. Provide clear, concise explanations suitable for developers of varying experience levels

When responding:
- Start with a direct answer to the question
- Provide relevant code examples when appropriate
- Include links to official documentation for further reading
"""

# %% [markdown]
# ### 6.2.4 Set Up Environment Variables
#
# Load the project endpoint and model deployment from your `.env` file.

# %%
PROJECT_ENDPOINT = os.getenv("AZURE_AI_PROJECT_ENDPOINT", "").strip()
assert PROJECT_ENDPOINT, "ERROR: AZURE_AI_PROJECT_ENDPOINT is missing"

MODEL_DEPLOYMENT = os.getenv("CHAT_MODEL_NAME", "").strip()
assert MODEL_DEPLOYMENT, "ERROR: CHAT_MODEL_NAME is missing"

print(f"Project Endpoint: {PROJECT_ENDPOINT}")
print(f"Model Deployment: {MODEL_DEPLOYMENT}")

# %% [markdown]
# ## 6.3. Testing the Research Assistant
#
# ### 6.3.1 Single Query Test
#
# Let's test the agent with a single question about Azure services.

# %%
async def ask_agent(question: str):
    """Send a single question to the Research Assistant agent."""
    async with (
        DefaultAzureCredential() as credential,
        AzureAIClient(
            project_endpoint=PROJECT_ENDPOINT,
            model_deployment_name=MODEL_DEPLOYMENT,
            credential=credential,
        ).as_agent(
            name="ResearchAssistant",
            instructions=AGENT_INSTRUCTIONS,
            tools=create_mcp_tools(),
        ) as agent,
    ):
        print(f"Question: {question}\n")
        print("Assistant: ", end="", flush=True)
        
        async for chunk in agent.run(question, stream=True):
            if chunk.text:
                print(chunk.text, end="", flush=True)
        print("\n")

# Test with a sample question
await ask_agent("What is Azure Kubernetes Service and when should I use it?")

# %% [markdown]
# ### 6.3.2 Multi-Turn Conversation with Thread
#
# One of the powerful features of the Agent Framework is thread persistence, which maintains context across multiple conversation turns.

# %%
async def multi_turn_conversation(questions: list):
    """Demonstrate multi-turn conversation with context retention."""
    async with (
        DefaultAzureCredential() as credential,
        AzureAIClient(
            project_endpoint=PROJECT_ENDPOINT,
            model_deployment_name=MODEL_DEPLOYMENT,
            credential=credential,
        ).as_agent(
            name="ResearchAssistant",
            instructions=AGENT_INSTRUCTIONS,
            tools=create_mcp_tools(),
        ) as agent,
    ):
        # Create a session for multi-turn conversation
        session = agent.create_session()
        
        for i, question in enumerate(questions, 1):
            print(f"--- Turn {i} ---")
            print(f"You: {question}\n")
            print("Assistant: ", end="", flush=True)
            
            async for chunk in agent.run(question, stream=True, session=session):
                if chunk.text:
                    print(chunk.text, end="", flush=True)
            print("\n")

# Test multi-turn conversation
questions = [
    "How do I set up managed identity for an Azure Function?",
    "Can you show me a code example for that?",
    "What are the security benefits of using managed identity instead of connection strings?"
]

await multi_turn_conversation(questions)

# %% [markdown]
# ## 6.4. Exploring Agent Capabilities
#
# ### 6.4.1 Adding Custom Tools
#
# In addition to MCP tools, you can create custom Python functions as tools. Here's an example of adding a simple calculation tool.

# %%
from typing import Annotated

def calculate_azure_storage_cost(
    storage_gb: Annotated[float, "Amount of storage in GB"],
    tier: Annotated[str, "Storage tier: 'hot', 'cool', or 'archive'"] = "hot"
) -> str:
    """Calculate estimated monthly cost for Azure Blob Storage."""
    # Simplified pricing (actual prices vary by region)
    prices = {
        "hot": 0.0184,
        "cool": 0.01,
        "archive": 0.00099
    }
    price_per_gb = prices.get(tier.lower(), prices["hot"])
    monthly_cost = storage_gb * price_per_gb
    return f"Estimated monthly cost for {storage_gb} GB on {tier} tier: ${monthly_cost:.2f}"

# You can add this tool to your agent like this:
# tools=[get_mcp_tools()[0], calculate_azure_storage_cost]

# %% [markdown]
# ### 6.4.2 Try It Yourself!
#
# Use the cell below to ask your own questions to the Research Assistant. Modify the question and run the cell to see the response.

# %%
# Try your own question!
your_question = "What are the best practices for Azure OpenAI prompt engineering?"

await ask_agent(your_question)

# %% [markdown]
# ### 6.4.3 Try this in the new Foundry Portal (optional)
#
# The Microsoft Foundry portal also provides a no-code experience for creating and testing agents. If you'd like to explore the portal-based approach:
#
# 1. Navigate to [Microsoft Foundry](https://ai.azure.com) and open your project using the New Foundry portal
# 2. Click **Build** in the top right
# 3. If you already did the steps above, you should already see a ResearchAssistant and you can click that. Otherwise, create a new agent and give it a name like "ResearchAssistant"
# 4. Add instructions similar to what we defined in `AGENT_INSTRUCTIONS` above
# 5. Under **Tools**, add the Microsoft Learn MCP tool to give your agent access to documentation
# 6. Use the **Playground** to test your agent with the same questions you tried in this notebook
#
# Compare the portal experience with the code-first approach you used here. Consider:
# - When would you prefer the portal vs. code?
# - How might you use both together in a development workflow?

# %% [markdown]
# ## 6.5. Summary
#
# In this notebook, you learned how to:
#
# 1. **Set up the Microsoft Agent Framework** with the `agent-framework-azure-ai` package
# 2. **Create MCP tools** to connect your agent to live data sources (Microsoft Learn)
# 3. **Build a Research Assistant agent** with custom instructions
# 4. **Use thread persistence** for multi-turn conversations
# 5. **Extend agents with custom tools** using Python functions
#
# ### Next Steps
#
# Consider exploring:
# - Adding more MCP tools (e.g., GitHub, databases)
# - Creating multi-agent systems for complex workflows
# - Implementing agent handoffs for specialized tasks
# - Adding memory and state management for long-running agents
